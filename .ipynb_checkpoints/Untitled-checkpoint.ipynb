# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
   np.random.rand(20, 3) ,
   columns= ['a' ,'b' ,'c']
)
df
# Out:
#            a         b         c
# 0   0.399648  0.337085  0.692139
# 1   0.804012  0.957144  0.168608
# 2   0.763111  0.823449  0.914280
# 3   0.941089  0.927111  0.502925
# 4   0.188558  0.904370  0.803692
# 5   0.757918  0.020787  0.911017
# 6   0.456299  0.659705  0.921585
# 7   0.206655  0.316989  0.554837
# 8   0.385832  0.303668  0.569711
# 9   0.973656  0.297928  0.938008
# 10  0.034427  0.226390  0.416612
# 11  0.799629  0.481701  0.691857
# 12  0.381312  0.283424  0.822682
# 13  0.955604  0.764348  0.491272
# 14  0.309444  0.301394  0.046414
# 15  0.378453  0.097072  0.037812
# 16  0.126851  0.536932  0.240124
# 17  0.136713  0.915982  0.774912
# 18  0.352565  0.271708  0.364444
# 19  0.166340  0.040846  0.298749
